# %% [markdown]
# ![picture](https://prowly-uploads.s3.eu-west-1.amazonaws.com/uploads/4626/assets/71776/large_logo_wsb_poziom.jpg)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive
# Out:
# /content/gdrive/My Drive

# %%
# !ls
# Out:
#  100APPLE
# '5 - Diagnoza społeczna 2015 zmienne.docx'
#  AI_datasets
#  AI.docx
#  AW
#  BadanieRuchuTurystycznegoGdansk_Szymikowska.ipynb
# 'Bishop - Neural Networks For Pattern Recognition.pdf'
#  CarPrice_Assignment.csv
#  cleansed_data.csv
#  cleansed_data.xlsx
# 'Data Scientist. Anality danych 09-11 kwietnia 2021.pdf'
# 'Dokument bez tytułu.gdoc'
#  Dokumenty
#  Działki.gsheet
#  EKONOMETRIA
#  epdf.pub_outliers-in-statistical-data-probability-amp-mathe.pdf
#  final.mp3
#  GBM.ipynb
#  gbm_trials.csv
#  income_evaluation.csv
#  Invicta_zadanie_1.ipynb
#  Magisterka
# 'Metody Sztucznej Inteligencji'
# 'Modele nieparametryczne.docx'
# 'Modele nieparametryczne Krystian Zielinski 236879.R'
# 'Modele nieparametryczne.RData'
#  Modele_scoringowe.docx
# 'Modelowanie parametryczne'
#  MR
#  Outlier_Analysis.pdf
#  outliers_detection_using_iForest.ipynb
# 'Python skrypty'
#  Samouczace-sie-sztuczne-sieci-neuronowe-w-grupowaniu-i-klasyfikacji-danych-Teoria-i-zastosowania-w-ekonomii.pdf
# ...

# %%
# %cd /content/gdrive/My Drive/AI_datasets
# Out:
# /content/gdrive/My Drive/AI_datasets

# %%
# !ls
# Out:
#  2017_Financial_Data.csv      'Intel Image Classification demo'
#  BRAdata1.xlsx		       logs
#  CarPrice_Assignment.csv       Lyrics
#  DL_BRAdata.xlsx	       marketing_campaign.csv
#  house_price_prediction.csv    Music_genre
#  insurance.csv		       planesnet_split
#  insurance_kz.csv	       StormsData.csv
# 'Intel Image Classification'

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# load data 

storms = pd.read_csv("StormsData.csv")

# %%
storms.head()
# Out:
#    Unnamed: 0 name  year  month  day  hour   lat  long               status  \
# 0           1  Amy  1975      6   27     0  27.5 -79.0  tropical depression
# 1           2  Amy  1975      6   27     6  28.5 -79.0  tropical depression
# 2           3  Amy  1975      6   27    12  29.5 -79.0  tropical depression
# 3           4  Amy  1975      6   27    18  30.5 -79.0  tropical depression
# 4           5  Amy  1975      6   28     0  31.5 -78.8  tropical depression
#
#    category  wind  pressure  ts_diameter  hu_diameter
# 0        -1    25      1013          NaN          NaN
# 1        -1    25      1013          NaN          NaN
# 2        -1    25      1013          NaN          NaN
# 3        -1    25      1013          NaN          NaN
# 4        -1    25      1012          NaN          NaN

# %%
storms.dtypes
# Out:
# Unnamed: 0       int64
# name            object
# year             int64
# month            int64
# day              int64
# hour             int64
# lat            float64
# long           float64
# status          object
# category         int64
# wind             int64
# pressure         int64
# ts_diameter    float64
# hu_diameter    float64
# dtype: object

# %% [markdown]
# ## Część 1 - statystyki opisowe

# %% [markdown]
# **1. Policz srednia i mediane dla predkosci wiatru na swiecie w calym badanym okresie (dane storms).**

# %% [markdown]
# **2. Policz srednie i mediany dla wiatrow z poszczegolnych huraganow. Czy przecietne poziomy roznia sie od siebie znaczaco?**

# %% [markdown]
# **3. Czy rozklad huraganow 2015 rozni sie znaczaco rozkladu huraganow w 2014? Dokonaj (wstepnej) wizualnej weryfikacji**

# %% [markdown]
# **4. Czy rozklad huraganow 2015 rozni sie znaczaco rozkladu huraganow w 2014? Dokonaj analizy stastycznej (wykorzystaj znane Ci statystyki opisowe).**

# %% [markdown]
# **5. Sprawdz czy latach 2010 - 2015 wystepuja anomalie w sztormach.**

# %% [markdown]
# ## Część 2 - wnioskowanie statystyczne

# %% [markdown]
# **6. Za pomoca testu statystycznego sprawdz czy przecietna sila wiatrow w latach 2010 - 2015 roznila sie od 65.**

# %% [markdown]
# <p> Interpretacja: </p>
# ....................

# %% [markdown]
# **7. Za pomoca testu statystycznego sprawdz czy przecietna sila wiatrow w roku 2014 i 2015 roznila sie statystycznie od siebie.**

# %% [markdown]
# <p> Interpretacja: </p>
# ..............

# %% [markdown]
# **8. Czy rozklad wiatrow w 2014 roku roznil sie znaczaco w stosunku do rozkladow wiatrow w 2015.**

# %% [markdown]
# <p> Interpretacja: </p>
#
# ...................

# %% [markdown]
# **9. Sprawdz czy rozklad w 2014 i w 2015 jest rozkladem normalnym**

# %% [markdown]
# <p> Interpretacja: </p>
# .....................

# %% [markdown]
# <p> Interpretacja: </p>
#  .....................

# %% [markdown]
# **10. Sprawdz czy istnieje zaleznosc liniowa miedzy sila wiatrow a cisnieniem atmosferycznym oraz podej sile zaleznosci w danych storms.**

# %% [markdown]
# <p> Interpretacja: </p>
# ........................
